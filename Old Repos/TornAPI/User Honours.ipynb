# %%
from TornAPI.Torn import User
import datetime as dt
from pyspark.sql.functions import lit

user_api = User(dbutils.secrets.get("Personal", "TornAPI"))

# %%
honor_data = user_api.get_honors()

sp_honors = spark.createDataFrame(honor_data["honors"])

sp_honors.write.format("delta").mode("overwrite").saveAsTable("torn.user.honors")
