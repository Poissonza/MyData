# %%
import yaml
import pandas as pd

# %%
with open("botc_data.yml", "r") as f:
    data = yaml.load(f.read(), Loader=yaml.FullLoader)
data.keys()
pd.DataFrame(data["result"])
# Out:
#       video outcome  number_of_days
# 0  240920.0    Evil             3.0
# 1       NaN    None             NaN
